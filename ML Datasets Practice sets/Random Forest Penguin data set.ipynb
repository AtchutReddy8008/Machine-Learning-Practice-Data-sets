# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,ConfusionMatrixDisplay
from sklearn.tree import plot_tree

# %%
df=sns.load_dataset("penguins")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df2=df.copy()
sex_counts = df2["sex"].value_counts()
print(sex_counts)
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
sex_counts = df2["sex"].value_counts()
print(sex_counts)
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns

# Load the penguins dataset
df = sns.load_dataset("penguins")

# Create a copy of the DataFrame
df2 = df.copy()

# Check the value counts of the "sex" column
sex_counts = df2["sex"].value_counts()

print(sex_counts)
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df["sex"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
df.sex.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.sex.value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
k=pd.get_dummies(df.sex,drop_first=True)

# %%
df.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
m=pd.get_dummies(df.island,drop_first=True)

# %%
newdf=pd.concat([df,m,k])

# %%
newdf
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338     NaN        NaN             NaN            NaN                NaN
# 340     NaN        NaN             NaN            NaN                NaN
# 341     NaN        NaN             NaN            NaN                NaN
# 342     NaN        NaN             NaN            NaN                NaN
# 343     NaN        NaN             NaN            NaN                NaN
#
#      body_mass_g     sex Dream Torgersen   Male
# ...

# %%
newdf.drop(["sex","island"],axis=1,inplace=True)

# %%
newdf
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338     NaN             NaN            NaN                NaN          NaN
# 340     NaN             NaN            NaN                NaN          NaN
# 341     NaN             NaN            NaN                NaN          NaN
# 342     NaN             NaN            NaN                NaN          NaN
# 343     NaN             NaN            NaN                NaN          NaN
#
#     Dream Torgersen   Male
# 0     NaN       NaN    NaN
# ...

# %%
Y=newdf.species
Y.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 4    Adelie
# 5    Adelie
# Name: species, dtype: object

# %%
Y.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo', nan], dtype=object)

# %%
Y=Y.map({"Adelie":0,'Chinstrap':1,'Gentoo':2})

# %%
Y.head()
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 4    0.0
# 5    0.0
# Name: species, dtype: float64

# %%
X=newdf

# %%
X
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338     NaN             NaN            NaN                NaN          NaN
# 340     NaN             NaN            NaN                NaN          NaN
# 341     NaN             NaN            NaN                NaN          NaN
# 342     NaN             NaN            NaN                NaN          NaN
# 343     NaN             NaN            NaN                NaN          NaN
#
#     Dream Torgersen   Male
# 0     NaN       NaN    NaN
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (699, 8)
# (300, 8)
# (699,)
# (300,)

# %% [markdown]
# ### Training random Forest Classification on Training Set

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=5,criterion='entropy',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4068\1892456006.py in ?()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 classifier=RandomForestClassifier(n_estimators=5,criterion='entropy',random_state=0)
# ----> 3 classifier.fit(X_train,y_train)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     344         """
#     345         # Validate or convert input data
#     346         if issparse(y):
# ...
